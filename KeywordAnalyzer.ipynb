# %%
import pandas as pd
import numpy as np
import nltk
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.preprocessing import LabelEncoder
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import re
import matplotlib.pyplot as plt
import nltk, sys

# %matplotlib inline
# Out:
# G:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df = pd.read_csv('doc.csv', encoding='latin-1')

# %%
def pre_proc(a):
    a['JD'] = a['JD'].apply(lambda x: " ".join(x.lower() for x in x.split()))
    a['JD'] = a['JD'].str.replace('[^\w\s]','')
    return a

# %%
df = df.dropna(axis=0)

# %%
pre_proc(df)
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                 CompanyName  \
# 0                    Abbott
# 1                    AbbVie
# 2                 Accenture
# 3                       ADP
# 4                     Aetna
# 5                       AIG
# 6        Allstate Insurance
# 7                    Anthem
# 8                   Aramark
# 9                      AT&T
# 10                     BASF
# 11                   Boeing
# 12        Colgate-Palmolive
# 13        Cox Communication
# 14                  cummins
# 15               CVS health
# 16    Eli Lilly and company
# 17                   Exelon
# 18          Express Scripts
# 19                       EY
# 20           General Motors
# 21                Hershey's
# 22                   Humana
# 23                  Jcpenny
# 24                      JnJ
# 25                  Kellogg
# 26                  KeyBank
# 27                     KPMG
# 28                 Marriott
# 29               MasterCard
# ...                     ...
# 1469                 Random
# 1470                 Random
# 1471                 Random
# 1472                 Random
# 1473                 Random
# 1474                 Random
# 1475                 Random
# 1476                 Random
# 1477                 Random
# 1478                 Random
# 1479                 Random
# 1480                 Random
# 1481                 Random
# 1482                 Random
# 1483                 Random
# 1484                 Random
# 1485                 Random
# 1486                 Random
# 1487                 Random
# 1488                 Random
# 1489                 Random
# 1490                 Random
# 1491                 Random
# 1492                 Random
# 1493                 Random
# 1494                 Random
# 1495                 Random
# 1496                 Random
# 1497                 Random
# 1498                 Random
#
#                                                      JD  TextioCat  \
# 0     job description major responsibilities externa...        4.0
# 1     job description research project opportunities...        5.0
# 2     accenture technology powers our clients busine...        5.0
# 3     job description adp is looking for a product d...        2.0
# 4     job description position summary the product s...        5.0
# 5     job description position description responsib...        3.0
# 6     where good people build rewarding careers thin...        5.0
# 7     job description your talent our vision at anth...        3.0
# 8     job description overview aramark nyse armk is ...        3.0
# 9     job description job summary manages designs de...        2.0
# 10    what you can expect in this role you will be r...        4.0
# 11    ob description boeing is the worlds largest ae...        1.0
# 12    job description description data scientist  di...        4.0
# 13    description summary the executive assistant pr...        4.0
# 14    engineering graduates  bebtech or memtech in e...        2.0
# 15    job description do you have the ability to see...        4.0
# 16    job description responsibilities project execu...        4.0
# 17    job description description primary purpose of...        5.0
# 18    job description position summary the sr softwa...        5.0
# 19    job description our practice the data and anal...        5.0
# 20    job description general motors israel herzelia...        4.0
# 21    job description description primary purpose of...        5.0
# 22    job description primary location uskylouisvill...        1.0
# 23    ob description description data scientist  dig...        4.0
# 24    role overview this job exists to manage and de...        4.0
# 25    job description we are always interested in he...        6.0
# 26    job description about the job job description ...        3.0
# 27    job description roles and responsibilities man...        1.0
# 28    job summary the senior area director of revenu...        2.0
# 29    job title senior data analyst hadoop python sa...        3.0
# ...                                                 ...        ...
# 1469  job description level 7 job  manager business ...        3.0
# 1470  job profile job title hr business partner corp...        5.0
# 1471  job profile job title hr business partner corp...        5.0
# 1472  job description manager  mi reporting  0000543...        3.0
# 1473  job description level job  manager  taxation i...        4.0
# 1474  role purpose overall high level summary of the...        6.0
# 1475  description  global service delivery is a busi...        3.0
# 1476  business analytics  business consulting role t...        5.0
# 1477  business analytics  business consulting role t...        5.0
# 1478  business analytics  business consulting role t...        5.0
# 1479  job description job code job title managermidd...        5.0
# 1480  job description level 8 job  manager finance i...        5.0
# 1481  job title financial planning  analysis and inv...        3.0
# 1482  type of experience law graduate experience pre...        4.0
# 1483  job description 1 job details position title m...        4.0
# 1484  job title manager department stress testing op...        5.0
# 1485  manager financial systems and integration cven...        6.0
# 1486  position profile summary about ey ey is a glob...        1.0
# 1487  position profile summary about ey ey is a glob...        1.0
# 1488  position profile summary about ey ey is a glob...        1.0
# 1489  job description manager  finance operations  0...        3.0
# 1490  career opportunities position managersr manage...        5.0
# 1491  requisition date 15th oct 2011 position title ...        1.0
# 1492  job description job code job title chief manag...        5.0
# 1493  job description job title chief manager hr rep...        1.0
# 1494  job description job code job title manager ban...        3.0
# 1495  job description job code band 3 reporting to h...        1.0
# 1496  ratings job title team leader department mcg h...        4.0
# 1497  about crisil ratings crisil ratings is indias ...        3.0
# 1498  job title mgr mktg ops  liquids department mar...        4.0
#
#       TextioScore
# 0            27.0
# 1            45.0
# 2            32.0
# 3            52.0
# 4            74.0
# 5            36.0
# 6            79.0
# 7             0.0
# 8            44.0
# 9            23.0
# 10           37.0
# 11           37.0
# 12           37.0
# 13           37.0
# 14           37.0
# 15           61.0
# 16           33.0
# 17           66.0
# 18           86.0
# 19           63.0
# 20           75.0
# 21           66.0
# 22           34.0
# 23           37.0
# 24           44.0
# 25           75.0
# 26           42.0
# 27           29.0
# 28           23.0
# 29           57.0
# ...           ...
# 1469         41.0
# 1470         29.0
# 1471         29.0
# 1472         38.0
# 1473         24.0
# 1474         36.0
# 1475         45.0
# 1476         10.0
# 1477         10.0
# 1478         10.0
# 1479         25.0
# 1480         30.0
# 1481         19.0
# 1482         34.0
# 1483         15.0
# 1484         29.0
# 1485         45.0
# 1486         50.0
# 1487         50.0
# 1488         50.0
# 1489         43.0
# 1490         23.0
# 1491         27.0
# 1492         46.0
# 1493         26.0
# 1494         25.0
# 1495         48.0
# 1496         28.0
# 1497         35.0
# 1498         14.0
#
# [1494 rows x 4 columns]

# %%
from pprint import pprint
import nltk
import yaml
import sys
import os
import re
import re

# %%
class Splitter(object):

    def __init__(self):
        self.nltk_splitter = nltk.data.load('tokenizers/punkt/english.pickle')
        self.nltk_tokenizer = nltk.tokenize.TreebankWordTokenizer()

    def split(self, text):
        """
        input format: a paragraph of text
        output format: a list of lists of words.
            e.g.: [['this', 'is', 'a', 'sentence'], ['this', 'is', 'another', 'one']]
        """
        sentences = self.nltk_splitter.tokenize(text)
        tokenized_sentences = [self.nltk_tokenizer.tokenize(sent) for sent in sentences]
        return tokenized_sentences

# %%
class POSTagger(object):

    def __init__(self):
        pass
        
    def pos_tag(self, sentences):
        """
        input format: list of lists of words
            e.g.: [['this', 'is', 'a', 'sentence'], ['this', 'is', 'another', 'one']]
        output format: list of lists of tagged tokens. Each tagged tokens has a
        form, a lemma, and a list of tags
            e.g: [[('this', 'this', ['DT']), ('is', 'be', ['VB']), ('a', 'a', ['DT']), ('sentence', 'sentence', ['NN'])],
                    [('this', 'this', ['DT']), ('is', 'be', ['VB']), ('another', 'another', ['DT']), ('one', 'one', ['CARD'])]]
        """

        pos = [nltk.pos_tag(sentence) for sentence in sentences]
        #adapt format
        pos = [[(word, word, [postag]) for (word, postag) in sentence] for sentence in pos]
        return pos

# %%
class DictionaryTagger(object):
    def __init__(self, dictionary_paths):
        files = [open(path, 'r') for path in dictionary_paths]
        dictionaries = [yaml.load(dict_file) for dict_file in files]
        map(lambda x: x.close(), files)
        self.dictionary = {}
        self.max_key_size = 0
        for curr_dict in dictionaries:
            for key in curr_dict:
                if key in self.dictionary:
                    self.dictionary[key].extend(curr_dict[key])
                else:
                    self.dictionary[key] = curr_dict[key]
                    self.max_key_size = max(self.max_key_size, len(key))

    def tag(self, postagged_sentences):
        return [self.tag_sentence(sentence) for sentence in postagged_sentences]

    def tag_sentence(self, sentence, tag_with_lemmas=False):
        """
        the result is only one tagging of all the possible ones.
        The resulting tagging is determined by these two priority rules:
            - longest matches have higher priority
            - search is made from left to right
        """
        tag_sentence = []
        N = len(sentence)
        if self.max_key_size == 0:
            self.max_key_size = N
        i = 0
        while (i < N):
            j = min(i + self.max_key_size, N) #avoid overflow
            tagged = False
            while (j > i):
                expression_form = ' '.join([word[0] for word in sentence[i:j]]).lower()
                expression_lemma = ' '.join([word[1] for word in sentence[i:j]]).lower()
                if tag_with_lemmas:
                    literal = expression_lemma
                else:
                    literal = expression_form
                if literal in self.dictionary:
                    #self.logger.debug("found: %s" % literal)
                    is_single_token = j - i == 1
                    original_position = i
                    i = j
                    taggings = [tag for tag in self.dictionary[literal]]
                    tagged_expression = (expression_form, expression_lemma, taggings)
                    if is_single_token: #if the tagged literal is a single token, conserve its previous taggings:
                        original_token_tagging = sentence[original_position][2]
                        tagged_expression[2].extend(original_token_tagging)
                    tag_sentence.append(tagged_expression)
                    tagged = True
                else:
                    j = j - 1
            if not tagged:
                tag_sentence.append(sentence[i])
                i += 1
        return tag_sentence

# %%
def sentence_score(sentence_tokens, previous_token, acum_score):    
    if not sentence_tokens:
        return acum_score
    else:
        current_token = sentence_tokens[0]
        tags = current_token[2]
        token_score = sum([value_of(tag) for tag in tags])
        if previous_token is not None:
            previous_tags = previous_token[2]
            if 'inc' in previous_tags:
                token_score *= 2.0
            elif 'dec' in previous_tags:
                token_score /= 2.0
            elif 'inv' in previous_tags:
                token_score *= -1.0
        return sentence_score(sentence_tokens[1:], current_token, acum_score + token_score)

def sentiment_score(review):
    return sum([sentence_score(sentence, None, 0.0) for sentence in review])

# %%
def value_of(sentiment):
    if sentiment == 'positive': return 1
    if sentiment == 'negative': return -1
    return 0

def sentiment_score(review):    
    return sum ([value_of(tag) for sentence in dict_tagged_sentences for token in sentence for tag in token[2]])

# %%
i=0
while (i<1493):
    text= df['JD'][i]
    splitter = Splitter()
    postagger = POSTagger()
    splitted_sentences = splitter.split(text)
    pos_tagged_sentences = postagger.pos_tag(splitted_sentences)
    dicttagger = DictionaryTagger([ 'BagOfFeminine.yml', 'BagOfMasculine.yml', 'inc.yml', 'dec.yml','inv.yml'])
    dict_tagged_sentences = dicttagger.tag(pos_tagged_sentences)
    y=sentiment_score(dict_tagged_sentences)
    x=0.1*y
    df['Calculator']=y
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
